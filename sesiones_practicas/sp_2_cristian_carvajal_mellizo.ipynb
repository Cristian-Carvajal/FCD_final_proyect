# %% [markdown]
# <img src="imgs\banner_fcd.jpg" alt="bannersp" width="1100"  height="150">

# %% [markdown]
# ## <span style="color:#2F749F;"><strong>📦 Sesión práctica 2: Análisis Univariado, bivariado y multivariado</strong></span>
# ---
# <p align="right">
#   <a href="https://colab.research.google.com/#create=true" target="_blank">
#     <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Abrir en Colab"/>
#   </a>
# </p>

# %% [markdown]
# ## <span style="color:black;"><strong>Datos del estudiante</strong></span>

# %%
nombre = input("📝 Ingresa tu nombre completo: ")
correo = input("📧 Ingresa tu correo electrónico: ")
cedula = input("🔢 Ingresa los últimos 6 dígitos de tu cédula: ")
# Out:
# 📝 Ingresa tu nombre completo: a
# 📧 Ingresa tu correo electrónico: a
# 🔢 Ingresa los últimos 6 dígitos de tu cédula: a

# %% [markdown]
# ## <span style="color:black;"><strong>Parte 1: Análisis Univariado</strong></span>

# %% [markdown]
# ### <span style="color:#2F749F;"><strong>Ejercicio 1: Cálculo de medidas de tendencia central</strong></span>
#
# A partir de una muestra simulada de ingresos, calcula la **media, mediana y moda**, y luego a interpretarlas.
#
# 1. Usa el número base `544038` (debes reemplazarlo con los últimos 6 dígitos de tu documento de identificación).
# 2. Con este número genera una semilla (`np.random.seed`) para que los resultados sean reproducibles.
# 3. Los ingresos se simulan con una distribución normal:
#    - Media teórica: `(base % 10) + 2`
#    - Desviación estándar: `7`
#    - Tamaño de muestra: `150`
# 4. Los valores negativos se reemplazan por cero (pues los ingresos no pueden ser negativos).
# 5. Grafica tus resultados (ver imagen de ejemplo)
#
# <p align="center">
#     <img src="imgs\sp_2_e1.png" alt="sp_2_e1" width="900"  height="400">
# </p>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns

prueba = 544038
np.random.seed(prueba)

data = np.random.normal(loc=(prueba % 10) + 2, scale=7, size=150).round(0)

media = np.mean(data)
mediana = np.median(data)
moda = stats.mode(data, keepdims=True)[0][0]

print(f"Media:   {media:.2f}")
print(f"Mediana: {mediana:.2f}")
print(f"Moda:    {moda:.2f}")

# Visualización
plt.boxplot(data, vert=False)
plt.title("Edad de las personas que ingresaron a un parque de diversiones")
plt.xlabel("Cantidad de personas")
plt.ylabel("Variable: Edad")
plt.axvline(media, color='red', linestyle='--', label=f'Media: {media:.2f}')
plt.axvline(mediana, color='green', linestyle='-', label=f'Mediana: {mediana:.2f}')
plt.axvline(moda, color='blue', linestyle=':', label=f'Moda: {moda:.2f}')
plt.legend()
plt.show()
# Out:
# Media:   10.14
# Mediana: 10.00
# Moda:    11.00

# %%
# Visualización
plt.figure(figsize=(10, 5))
sns.histplot(data, bins=10, kde=False, color="#2F749F")

# Líneas de tendencia central
plt.axvline(media, color='red', linestyle='--', linewidth=2, label=f'Media: {media:.2f}')
plt.axvline(mediana, color='green', linestyle='-', linewidth=2, label=f'Mediana: {mediana:.2f}')
plt.axvline(moda, color='purple', linestyle=':', linewidth=2, label=f'Moda: {moda:.2f}')

# Estética

plt.title("Edad de las personas que ingresaron a un parque de diversiones")
plt.xlabel("Edad")
plt.ylabel("Cantidad de personas")
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
data
# Out:
# array([ 3.,  8.,  2.,  9.,  8., 20., 10.,  9., 13., 20.,  8., 13., 13.,
#         0.,  1.,  7., 11., 20., 20., 33.,  9.,  5., -5., 19.,  4., 17.,
#        -1.,  5., -0.,  7., 21., 22.,  9., 14.,  2., 11.,  5., 16.,  8.,
#        -0.,  0., 16.,  3., 12., -6., 12.,  1., 11.,  6., -1.,  3., 17.,
#         5., 12., 19., 14.,  5., 14., 15., 13.,  8.,  1., 13., 18.,  9.,
#         4.,  6.,  7., 11., 15.,  9., 18., 11., 21., 12., 13., 22., 12.,
#        18., 11.,  6.,  9.,  3., -7., 13., 18., 20., 14.,  7., 15.,  5.,
#        22.,  1.,  2.,  6., 25.,  8., 15.,  9.,  4., 20., 17.,  1., 14.,
#         6.,  6., 10., 10., 12., 11.,  8., 15.,  5., -2.,  7., 17., 14.,
#        11., 18.,  8.,  4., 11., 23., 22., 12., 11.,  3., 13., 10., 10.,
#        13., 10.,  5., 15.,  7., 10., 12., 12., 20., 18., 14.,  6.,  3.,
#         1.,  1.,  2., 16., 16., 13., -1.])

# %% [markdown]
# #### Descripción inicial
#
# Con el objetivo de querer brindar una vista un poco mas realista en este trabajo practico, lo primero que quise realizar fue visualizar los datos otorgados por la semilla designada.
#
# Tras ver de forma superficial los datos, podemos decir que estos pueden llegar a representar la edad de un grupo de personas. Con base a esto, para la realización de este ejercicio he decidido tomar esta variable como la edad que presentan las personas que ingresan a un parque de diversiones.

# %%
data = np.clip(data, a_min=0, a_max=None)

# %%
data
# Out:
# array([ 3.,  8.,  2.,  9.,  8., 20., 10.,  9., 13., 20.,  8., 13., 13.,
#         0.,  1.,  7., 11., 20., 20., 33.,  9.,  5.,  0., 19.,  4., 17.,
#         0.,  5.,  0.,  7., 21., 22.,  9., 14.,  2., 11.,  5., 16.,  8.,
#         0.,  0., 16.,  3., 12.,  0., 12.,  1., 11.,  6.,  0.,  3., 17.,
#         5., 12., 19., 14.,  5., 14., 15., 13.,  8.,  1., 13., 18.,  9.,
#         4.,  6.,  7., 11., 15.,  9., 18., 11., 21., 12., 13., 22., 12.,
#        18., 11.,  6.,  9.,  3.,  0., 13., 18., 20., 14.,  7., 15.,  5.,
#        22.,  1.,  2.,  6., 25.,  8., 15.,  9.,  4., 20., 17.,  1., 14.,
#         6.,  6., 10., 10., 12., 11.,  8., 15.,  5.,  0.,  7., 17., 14.,
#        11., 18.,  8.,  4., 11., 23., 22., 12., 11.,  3., 13., 10., 10.,
#        13., 10.,  5., 15.,  7., 10., 12., 12., 20., 18., 14.,  6.,  3.,
#         1.,  1.,  2., 16., 16., 13.,  0.])

# %%
media = np.mean(data)
mediana = np.median(data)
moda = stats.mode(data, keepdims=True)[0][0]

print(f"Media:   {media:.2f}")
print(f"Mediana: {mediana:.2f}")
print(f"Moda:    {moda:.2f}")

# Visualización
plt.boxplot(data, vert=False)
plt.title("Edad de las personas que ingresaron a un parque de diversiones")
plt.xlabel("Cantidad de personas")
plt.ylabel("Variable: Edad")
plt.axvline(media, color='red', linestyle='--', label=f'Media: {media:.2f}')
plt.axvline(mediana, color='green', linestyle='-', label=f'Mediana: {mediana:.2f}')
plt.axvline(moda, color='blue', linestyle=':', label=f'Moda: {moda:.2f}')
plt.legend()
plt.show()
# Out:
# Media:   10.29
# Mediana: 10.00
# Moda:    0.00

# %%
# Visualización
plt.figure(figsize=(10, 5))
sns.histplot(data, bins=10, kde=False, color="#2F749F")

# Líneas de tendencia central
plt.axvline(media, color='red', linestyle='--', linewidth=2, label=f'Media: {media:.2f}')
plt.axvline(mediana, color='green', linestyle='-', linewidth=2, label=f'Mediana: {mediana:.2f}')
plt.axvline(moda, color='purple', linestyle=':', linewidth=2, label=f'Moda: {moda:.2f}')

# Estética
plt.title("Edad de las personas que ingresaron a un parque de diversiones", fontsize=14)
plt.xlabel("Edad", fontsize=12)
plt.ylabel("Cantidad de personas", fontsize=12)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Variación en las medidas de tendencia central
#
# Lo primero que podemos evidenciar, es el cambio que se genera sobre las medidas de moda y media luego de transformar todos los datos negativos presentes en nuestro conjunto de datos. Evidenciamos como tras convertir estos datos negativos en 0 (ya que una persona no puede tener edad negativa) la distribución pierde su normalidad y la edad que tienen la mayor cantidad de visitantes del parque es de 0 años.

# %% [markdown]
# ### <span style="color:#2F749F;"><strong>Ejercicio 2: Cálculo de medidas de dispersión</strong></span>
#
# A partir de la muestra generada en el Ejercicio 1, analiza qué tan dispersos están los datos respecto a su media. Calcula:
# 1. Rango
# 2. Varianza
# 3. Desviación estándar
# 4. Coeficiente de variación
# 5. Genera una gráfica con los resultados obtenidos (ver imagen de ejemplo)
#
# <p align="center">
#     <img src="imgs\sp_2_e2.png" alt="sp_2_e2" width="900"  height="400">
# </p>

# %%
# Cálculo de medidas de dispersión
media = np.mean(data)
minimo = np.min(data)
maximo = np.max(data)
rango = maximo - minimo
varianza = np.var(data, ddof=1)
desviacion = np.std(data, ddof=1)
coef_var = desviacion / media

print(f"Minimo:      {minimo:.2f}")
print(f"Maximo:      {maximo:.2f}")
print(f"rango:       {rango:.2f}")
print(f"varianza:    {varianza:.2f}")
print(f"desviacion:  {desviacion:.2f}")
print(f"coef_var:    {coef_var:.2f}")

# Visualización
sns.set_theme(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.histplot(data, bins=6, kde=True, color='skyblue')

# Líneas verticales
plt.axvline(media, color='green', linestyle='--', linewidth=2, label=f'Media = {media:.2f}')
plt.axvline(media + desviacion, color='purple', linestyle=':', linewidth=1.5, label=f'+1σ = {media + desviacion:.2f}')
plt.axvline(media - desviacion, color='purple', linestyle=':', linewidth=1.5, label=f'-1σ = {media - desviacion:.2f}')
plt.axvline(minimo, color='red', linestyle='-', linewidth=1.5, label=f'Mínimo = {minimo}')
plt.axvline(maximo, color='red', linestyle='-', linewidth=1.5, label=f'Máximo = {maximo}')

# Título y etiquetas
plt.title("Edad de las personas que ingresaron a un parque de diversiones")
plt.xlabel("Edad")
plt.ylabel("Cantidad de personas")
plt.legend()


# Recuadro con medidas
texto = (
    f"Rango: {rango}\n"
    f"Varianza: {varianza:.2f}\n"
    f"Desviación estándar: {desviacion:.2f}\n"
    f"Coef. de variación: {coef_var:.2f}"
)
plt.text(7.5, 3, texto, bbox=dict(facecolor='lightgreen', alpha=0.3), fontsize=10)

plt.tight_layout()
plt.show()
# Out:
# Minimo:      0.00
# Maximo:      33.00
# rango:       33.00
# varianza:    43.48
# desviacion:  6.59
# coef_var:    0.64

# %% [markdown]
# #### Medidas de dispersión
#
# Podemos decir que las edades de las personas que visitan el parque de atracciones varían en promedio 6 años con respecto a la edad media de este mismo grupo (10 años)

# %% [markdown]
# ### <span style="color:#2F749F;"><strong>Ejercicio 3: Cálculo de medidas de distribución</strong></span>
#
# A partir de la muestra generada en el Ejercicio 1, analiza la distribución de los datos. Calcula:
# 1. Asimetría
# 2. Curtosis
# 3. Realiza la comparación con la distribución normal (ver la imagen de ejemplo)
#
# <p align="center">
#     <img src="imgs\sp_2_e3.png" alt="sp_2_e3" width="900"  height="400">
# </p>

# %%
from scipy.stats import skew, kurtosis
import pandas as pd

# Estilo visual
sns.set_theme(style="whitegrid")

# Simulación de datos
data
df = pd.DataFrame({'Datos': data})

# Cálculo de métricas
asimetria = skew(df['Datos'])
curtosis_valor = kurtosis(df['Datos'])

# Visualización
plt.figure(figsize=(10, 6))
sns.histplot(df['Datos'], kde=True, color='skyblue', bins=15)
plt.axvline(df['Datos'].mean(), color='red', linestyle='--', label='Media')

# Anotaciones en la esquina superior izquierda
plt.text(0.05, 0.95, f"Asimetría: {asimetria:.2f}", transform=plt.gca().transAxes,
         fontsize=12, verticalalignment='top', bbox=dict(facecolor='white', alpha=0.6))
plt.text(0.05, 0.88, f"Curtosis: {curtosis_valor:.2f}", transform=plt.gca().transAxes,
         fontsize=12, verticalalignment='top', bbox=dict(facecolor='white', alpha=0.6))

# Títulos y etiquetas
plt.title("Edad de las personas que ingresaron a un parque de diversiones")
plt.xlabel("Edad")
plt.ylabel("Cantidad de personas")
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Medidas de distribución
#
# Tras analizar un poco mas los datos, podemos ver como estos no presentan una simetría, sino que tienen un sesgo positivo (con lo cual podemos decir que probablemente la mayor cantidad de personas que visitan nuestro parque son niños con una edad temprana)

# %% [markdown]
# ### <span style="color:#2F749F;"><strong>Ejercicio 4: Cálculo de medidas de percentiles</strong></span>
#
# A partir de la muestra generada en el Ejercicio 1, calcula los percentiles de tus datos. Calcula:
# 1. Percentiles
# 2. Deciles
# 3. Cuartiles
# 4. Grafica los anteriores percentiles calculados, sobre la distribución de tus datos (ver la imagen de ejemplo)
#
# <p align="center">
#     <img src="imgs\sp_2_e4.png" alt="sp_2_e4" width="900"  height="400">
# </p>

# %%
#np.percentile(data, 25)
# Estilo visual
sns.set_theme(style="whitegrid")

# Cálculo de percentiles clave
percentiles = {
    'P10': {'valor': np.percentile(data, 10), 'color': 'red', 'linestyle': '-'},
    'P25 (Q1)': {'valor': np.percentile(data, 25), 'color': 'orange', 'linestyle': '--'},
    'P50 (Mediana)': {'valor': np.percentile(data, 50), 'color': 'green', 'linestyle': '-.'},
    'P75 (Q3)': {'valor': np.percentile(data, 75), 'color': 'blue', 'linestyle': ':'},
    'P90': {'valor': np.percentile(data, 90), 'color': 'purple', 'linestyle': (0, (5, 2))}
}

# Cálculo de deciles (D1 a D9)
deciles = {f'D{i}': np.percentile(data, i * 10) for i in range(1, 10)}

# Visualización
plt.figure(figsize=(14, 7))
sns.histplot(data, kde=True, color='skyblue', bins=20)

# Líneas verticales para percentiles destacados
for etiqueta, props in percentiles.items():
    plt.axvline(props['valor'], color=props['color'], linestyle=props['linestyle'],
                linewidth=2)
    plt.text(props['valor'], plt.ylim()[1]*0.9, etiqueta,
             rotation=90, color=props['color'], fontsize=10,
             verticalalignment='center', horizontalalignment='right',
             backgroundcolor='white')

# Líneas más sutiles para deciles
for etiqueta, valor in deciles.items():
    plt.axvline(valor, color='gray', linestyle='--', alpha=0.3)
    plt.text(valor, plt.ylim()[1]*0.6, etiqueta,
             rotation=90, color='gray', fontsize=8,
             verticalalignment='center', horizontalalignment='right')

# Recuadro interpretativo
texto = (
    "Percentiles dividen en 100 partes\n"
    "Deciles dividen en 10 partes (D1 a D9)\n"
    "Cuantiles como Q1, Q2, Q3 son fracciones (0.25, 0.50, 0.75)\n"
    "Útiles para analizar posición relativa y desigualdad"
)
plt.text(0.98, 0.95, texto, transform=plt.gca().transAxes,
         fontsize=10, verticalalignment='top', horizontalalignment='right',
         bbox=dict(boxstyle="round,pad=0.5", facecolor="white", edgecolor="gray"))

# Títulos y estilo
plt.title("Distribución Normal con Percentiles y Deciles", fontsize=14, fontweight='bold')
plt.xlabel("Valor")
plt.ylabel("Frecuencia")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Percentiles
#
# Debido a la presencia de un sesgo positivo dentro de nuestros datos, podemos notar como al intentar dividir este conjunto de datos dentro de percentiles, vemos una gran variación en la distribución de los percentiles, la cual probablemente se este dando debido a la presencia de datos a típicos y a la transformación hecha con anterioridad sobre los datos negativos presente en nuestro conjunto de datos original.

# %% [markdown]
# ## <span style="color:black;"><strong>Parte 2: Análisis Bivariado</strong></span>

# %% [markdown]
# ### <span style="color:#2F749F;"><strong>Ejercicio 5: Análisis de correlación</strong></span>
#
# En esta segunda parte, genera **dos variables** a partir de tú número de cédula y realiza un análisis **bivariado** para calcular la relación entre ellas.
#
# 1. Use los **6 últimos dígitos** de su cédula como base (similar al Ejercicio 1).
# 2. Genere dos variables aleatorias (ejemplo: `ingresos` y `gastos`) con distribución normal, usando esa base como **semilla reproducible**.
# 3. Calcule los coeficientes de correlación de **Pearson** y **Spearman**.
# 4. Grafique las variables analizadas (ver la imagen de ejemplo)
# 5. Interprete los resultados.
#
# <p align="center">
#     <img src="imgs\sp_2_e5.png" alt="sp_2_e5" width="900"  height="400">
# </p>

# %%
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt

# Caso 1: Relación lineal
x1 = np.linspace(0, 7, 150)
y1 = 2 * x1 + np.random.normal(loc=(7 % 10) + 2, scale=7, size=150).round(0)

# Correlaciones
def calcular_correlaciones(x, y):
    pearson, _ = stats.pearsonr(x, y)
    spearman, _ = stats.spearmanr(x, y)
    return pearson, spearman

p1, s1 = calcular_correlaciones(x1, y1)

# Visualización
fig, ax = plt.subplots(figsize=(8, 5))  # Solo una subgráfica
ax.scatter(x1, y1, color="blue", alpha=0.7)
ax.set_title("Relación Lineal")
ax.set_xlabel("X")
ax.set_ylabel("Y")

# Agregar texto con las correlaciones
texto1 = f"Pearson: {p1:.2f}\nSpearman: {s1:.2f}"
ax.text(0.05, 0.95, texto1, transform=ax.transAxes,
        fontsize=11, verticalalignment='top',
        bbox=dict(boxstyle="round", facecolor="white", edgecolor="gray"))

plt.show()

# %% [markdown]
# ### <span style="color:#2F749F;"><strong>Ejercicio 6: Chi-Cuadrado</strong></span>
#
# En esta parte, analiza si existe **asociación estadística** entre dos variables categóricas simuladas a partir de tu número de cédula.
#
# 1. Usa los **6 últimos dígitos** de tu cédula como base para generar una semilla reproducible.
# 2. Simula una muestra de **60 personas** con dos variables categóricas:
#    - `Nivel educativo`: Básico, Medio, Superior.
#    - `Acceso a internet`: Sí, No.
# 3. Crea una **tabla de contingencia** entre ambas variables.
# 4. Aplica la **prueba de Chi cuadrado de independencia**.
# 5. Visualiza la distribución conjunta con un mapa de calor (ver la imagen de con la información de ejemplo).
# 6. Interpreta el resultado.
#
# <p align="center">
#     <img src="imgs\sp_2_e6.png" alt="sp_2_e6" width="900"  height="700">
# </p>
